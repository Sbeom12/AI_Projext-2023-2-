# %% [markdown]
# # 웹페이지 구현
# * 기본적으로 Python 백엔드 플랫폼인 Django를 이용할 예정.
# * 기본적인 웹페이지는 Figma를 이용해서 틀만 잡는다.
# * [참고자료](https://wikidocs.net/book/4223)

# %% [markdown]
# * 기본적인 웹 페이지 틀.
#
# ![image.png](data:image/png;base64,...)
